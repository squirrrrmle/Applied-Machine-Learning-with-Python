# %% [markdown]
# ![xd.png](data:image/png;base64,...)

# %%
import numpy as np
filename = '/content/drive/MyDrive/PCA.npy'
x = np.load(filename)
u, s, vh = np.linalg.svd(x)
res = 1
counter = 0
denomenator = np.sum(s)
m = 0
size = np.size(s)
# print(s)
res = 1
while (res > 0.2):
    m+=1
    numerator = np.sum(s[m:size])
    res = numerator/denomenator
print(m)
# Out:
# 12
