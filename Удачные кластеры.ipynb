# %% [markdown]
# ![xdd.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
from tqdm import tqdm
import scipy.stats as sts
import scipy as sc
import seaborn as sns
import matplotlib.pyplot as plt
import math
import scipy.special as sp
from sklearn.cluster import KMeans


np.random.seed(42)
df = pd.read_csv('/content/drive/MyDrive/Task_9/Task_9/1.csv', index_col = None)
df = df.drop('class', axis=1)
# print(df)
df = df.to_numpy()
print(df)
# plt.scatter(df.iloc[:,0], df.iloc[:,1])
# plt.show()

kmeans = KMeans(n_clusters=2,random_state=42).fit(df)

plt.figure()
plt.scatter(df[:,0], df[:,1], c=kmeans.labels_)
# Out:
# [[ 1.5       0.      ]
#  [ 1.50973   0.028461]
#  [ 1.51892   0.057289]
#  ...
#  [ 6.45966  -0.365675]
#  [ 6.4754   -0.244232]
#  [ 6.48885  -0.122326]]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
np.random.seed(42)
df = pd.read_csv('/content/drive/MyDrive/Task_9/Task_9/2.csv', index_col = None)
df = df.drop('class', axis=1)
df = df.to_numpy()
print(df)
# plt.scatter(df.iloc[:,0], df.iloc[:,1])
# plt.show()

kmeans = KMeans(n_clusters=4,random_state=42).fit(df)

plt.figure()
plt.scatter(df[:,0], df[:,1], c=kmeans.labels_)
# Out:
# [[ 2.74531  41.5491  ]
#  [-0.628169 41.1591  ]
#  [ 2.77995  40.7192  ]
#  ...
#  [72.4116   68.3206  ]
#  [74.0903   69.715   ]
#  [73.6169   71.9917  ]]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
np.random.seed(42)
df = pd.read_csv('/content/drive/MyDrive/Task_9/Task_9/3.csv', index_col = None)
df = df.drop('class', axis=1)
df = df.to_numpy()
# plt.scatter(df.iloc[:,0], df.iloc[:,1])
# plt.show()

kmeans = KMeans(n_clusters=2,random_state=42).fit(df)

plt.figure()
plt.scatter(df[:,0], df[:,1], c=kmeans.labels_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
np.random.seed(42)
df = pd.read_csv('/content/drive/MyDrive/Task_9/Task_9/4.csv', index_col = None)
df = df.drop('class', axis=1)
df = df.to_numpy()
print(df)
# plt.scatter(df.iloc[:,0], df.iloc[:,1])
# plt.show()

kmeans = KMeans(n_clusters=3,random_state=42).fit(df)

plt.figure()
plt.scatter(df[:,0], df[:,1], c=kmeans.labels_)
# Out:
# [[ 0.00000e+00 -9.33717e+00 -1.47976e+00]
#  [ 1.00000e+00 -4.46281e+00 -1.57614e-01]
#  [ 2.00000e+00 -5.48281e+00 -1.33823e+00]
#  ...
#  [ 8.73000e+02  7.74910e-01 -7.47183e+00]
#  [ 8.74000e+02  6.27570e-01 -7.36297e+00]
#  [ 8.75000e+02  8.26680e-01 -7.15329e+00]]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
np.random.seed(42)
df = pd.read_csv('/content/drive/MyDrive/Task_9/Task_9/5.csv', index_col = None)
df = df.drop('class', axis=1)
df = df.to_numpy()
print(df)
# plt.scatter(df.iloc[:,0], df.iloc[:,1])
# plt.show()

kmeans = KMeans(n_clusters=4,random_state=42).fit(df)

plt.figure()
plt.scatter(df[:,0], df[:,1], c=kmeans.labels_)
# Out:
# [[-0.1       0.5     ]
#  [-0.100126  0.510052]
#  [-0.100505  0.520098]
#  ...
#  [-0.400284  0.492467]
#  [-0.400126  0.494976]
#  [-0.400032  0.497487]]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
np.random.seed(42)
df = pd.read_csv('/content/drive/MyDrive/Task_9/Task_9/6.csv', index_col = None)
# df = df.drop('class', axis=1)
df = df.to_numpy()
print(df)
# plt.scatter(df.iloc[:,0], df.iloc[:,1])
# plt.show()

kmeans = KMeans(n_clusters=3,random_state=42).fit(df)

plt.figure()
plt.scatter(df[:,0], df[:,1], c=kmeans.labels_)
# Out:
# [[ 2.0000000e+00 -1.6032100e+00  3.6203900e-01  0.0000000e+00]
#  [ 3.0000000e+00 -1.6992800e+00 -3.8424600e-01  0.0000000e+00]
#  [ 4.0000000e+00 -2.2992900e+00 -3.5803800e-01  0.0000000e+00]
#  ...
#  [ 7.1200000e+02  2.3027400e+00  3.6626200e-01  2.0000000e+00]
#  [ 7.1300000e+02  1.0160678e+00  2.1349900e-01  2.0000000e+00]
#  [ 7.1400000e+02  1.5614350e+00 -1.7046400e-01  2.0000000e+00]]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
